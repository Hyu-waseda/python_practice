# %%
import pandas as pd

# %%
df = pd.read_csv("winequality-red.csv", sep=";")

# %%
import seaborn as sns

# %%
sns.histplot(df["volatile acidity"])
# Out:
# <AxesSubplot:xlabel='volatile acidity', ylabel='Count'>

# %%
sns.jointplot(x="volatile acidity", y="pH", data=df)
